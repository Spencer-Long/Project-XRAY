# %% [markdown]
# ---
# ---
# ---
# # ***SNR Analytics Inc. Liver NN Project V1.2***
#
# ![alt text](https://drive.google.com/uc?export=view&id=1XuXOK7SUYz5f_MJnbYUJE25PY4ESdREM)
#
# ### **Data Scientists: Spencer Long, Michael Vo**
#
# **In This Version:** Entire workflow is implemented into a Google Colab Notebook in a clean organized fashion. We organize pre-processing into a clean and organized format. Pipeline is created using Tensor Flow and Tensor Board for visualization and analysis.
#
# ---
# ---
# ---
